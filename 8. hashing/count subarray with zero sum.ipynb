# %%
def count0(arr):
    n=len(arr)
    d=dict()
    
    count=0
    
    prefix=0
    for i in range(n):
        prefix+=arr[i]
        
        if(prefix==0):
            count+=1
        
        al=0
        
        if(prefix-0 in d):
            al=d[prefix-0]
            
            count+=al
        
        d[prefix]+=1
    return count

# %%
count0([0,0,5,5,0,0])
# Out:
# 6
